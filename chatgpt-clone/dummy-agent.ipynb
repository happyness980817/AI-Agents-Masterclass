# %%
from agents import Agent, Runner, SQLiteSession

session = SQLiteSession("user_2", "ai-memory.db")

geaography_agent = Agent(
    name="Geo Expert Agent",
    instructions="You are a expert in geography, you answer questions related to them.",
    handoff_description="Use this to answer geography related questions.",  # The main agent reads this.
)

economics_agent = Agent(
    name="Economics Expert Agent",
    instructions="You are a expert in economics, you answer questions related to them.",
    handoff_description="Use this to answer economics questions.",
)

main_agent = Agent(
    name="Main Agent",
    instructions="You are a user facing agent. Transfer to the agent most capable of answering the user's question.",
    handoffs=[
        economics_agent,
        geaography_agent,
    ],
)

# %%
result = await Runner.run(
    main_agent,
    "Why do countries sell treasury bonds?",
    session=session,
)

print(result.last_agent.name)
print(result.final_output)
# Out:
# Main Agent
# To borrow money.
#
# Governments sell treasury bonds when spending exceeds tax revenue, or when they want to finance long-term projects. Investors buy them because they’re usually seen as safe and pay interest.
#
# In short: **countries sell treasury bonds to fund deficits and public spending.**
