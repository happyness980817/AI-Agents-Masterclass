# %%
from agents import Agent, Runner, function_tool, ItemHelpers


@function_tool
def get_weather(city: str):
    """Get weather by cities"""
    print(city)
    return "30 degrees Celcius"


agent = Agent(
    name="Assistant Agent",
    instructions="You are a helpful assistant. Use tools when needed to answer questions.",
    tools=[get_weather],
)

stream = Runner.run_streamed(
    agent, "Hello! What is the weather in the capital of Spain?"
)

async for event in stream.stream_events():

    if event.type == "raw_response_event":
        continue
    elif event.type == "agent_updated_stream_event":
        print("Agent updated to", event.new_agent.name)
    elif event.type == "run_item_stream_event":
        if event.item.type == "tool_call_item":
            print(event.item.raw_item.to_dict())
        elif event.item.type == "tool_call_output_item":
            print(event.item.output)
        elif event.item.type == "message_output_item":
            print(ItemHelpers.text_message_output(event.item))
    print("=" * 20)
# Out:
# Agent updated to Assistant Agent
# ====================
# {'arguments': '{"city":"Madrid"}', 'call_id': 'call_8FVuqCJZO2k1RA02jJAUgvcQ', 'name': 'get_weather', 'type': 'function_call', 'id': 'fc_058f6119d25e2c58006a5b2ddf792c8199afaa74abfe6ceda5', 'status': 'completed'}
# ====================
# Madrid
# 30 degrees Celcius
# ====================
# Madrid: 30°C
# ====================

# %%
from agents import Agent, Runner, function_tool, ItemHelpers


@function_tool
def get_weather(city: str):
    """Get weather by cities"""
    print(city)
    return "30 degrees Celcius"


agent = Agent(
    name="Assistant Agent",
    instructions="You are a helpful assistant. Use tools when needed to answer questions.",
    tools=[get_weather],
)

stream = Runner.run_streamed(
    agent,
    "Hello! How are you? I'm doing great. What is the weather in the capital of Spain?",
)

message = ""
args = ""

async for event in stream.stream_events():

    if event.type == "raw_response_event":
        event_type = event.data.type
        if event_type == "response.output_text.delta":
            message += event.data.delta
            print(message)
        elif event_type == "response.function_call_arguments.delta":
            args += event.data.delta
            print(args)
        elif event_type == "response.completed":
            message = ""
            args = ""
# Out:
# {"
# {"city
# {"city":"
# {"city":"Madrid
# {"city":"Madrid"}
# Madrid
# I
# I’m
# I’m doing
# I’m doing well
# I’m doing well,
# I’m doing well, thanks
# I’m doing well, thanks!
# I’m doing well, thanks! The
# I’m doing well, thanks! The weather
# I’m doing well, thanks! The weather in
# I’m doing well, thanks! The weather in Madrid
# I’m doing well, thanks! The weather in Madrid is
# I’m doing well, thanks! The weather in Madrid is
# I’m doing well, thanks! The weather in Madrid is 30
# I’m doing well, thanks! The weather in Madrid is 30°C
# I’m doing well, thanks! The weather in Madrid is 30°C.

# %%
from agents import Agent, Runner, function_tool, SQLiteSession

session = SQLiteSession("user_2", "ai-memory.db")


@function_tool
def get_weather(city: str):
    """Get weather by cities"""
    print(city)
    return "30 degrees Celcius"


agent = Agent(
    name="Assistant Agent",
    instructions="You are a helpful assistant. Use tools when needed to answer questions.",
    tools=[get_weather],
)

# %%
result = await Runner.run(
    agent,
    "Hello! How are you? Do you remember my name?",
    session=session,
)

print(result.final_output)
# Out:
# Hello Paul! I’m doing well, thanks for asking. How can I help you today?

# %%
await session.clear_session()
